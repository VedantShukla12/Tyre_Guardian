# %% [markdown]
# #Resize Images on your Google Drive

# %% [markdown]
# ## Clone the `object_detection_demo_flow` repository which also contains the resize script

# %%
repo_url = 'https://github.com/GotG/object_detection_demo_flow'
import os
# %cd /content
repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))
# !git clone {repo_url}
# %cd {repo_dir_path}
# !git pull
# Out:
# /content
# Cloning into 'object_detection_demo_flow'...
# remote: Enumerating objects: 3038, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3038 (delta 0), reused 0 (delta 0), pack-reused 3035
# Receiving objects: 100% (3038/3038), 229.08 MiB | 28.23 MiB/s, done.
# Resolving deltas: 100% (1375/1375), done.
# Updating files: 100% (2796/2796), done.
# /content/object_detection_demo_flow
# Already up to date.

# %% [markdown]
# #Mount your google drive

# %%
#mount your google drive.
#it will be visible in the file navigator on the left of this notebook
#there should be a folder in your drive with your data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # From the file browser on the left go to gdrive/My Drive and find your image folder, right click and copy the path, then paste it after --raw-dir between ' '
# # Make a new folder for the resized images
# # Resize the images in the folder(s) on your gdrive using the cell below
#
# --raw-dir is the path to the folder containing the images to be resized
# --save-dir is the path to the folder where to save the resized images
# --ext jpg  assigns the jpg extension to the resized files
# --target-size is the desired size

# %%
# !python resize_images.py --raw-dir '/content/gdrive/MyDrive/Train/defective' --save-dir '/content/gdrive/MyDrive/compressed_images/Train/defective' --ext jpg --target-size "(256,256)"
# Out:
# 1252 files to resize from directory `/content/gdrive/MyDrive/Train/defective` to target size:(256, 256)
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Done resizing 1252 files.
# Saved to directory: `/content/gdrive/MyDrive/compressed_images/Train/defective`

# %%
# !python resize_images.py --raw-dir '/content/gdrive/MyDrive/Train/good' --save-dir '/content/gdrive/MyDrive/compressed_images/Train/good' --ext jpg --target-size "(256,256)"
# Out:
# 1055 files to resize from directory `/content/gdrive/MyDrive/Train/good` to target size:(256, 256)
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
# !python resize_images.py --raw-dir '/content/gdrive/MyDrive/Test /defective' --save-dir '/content/gdrive/MyDrive/compressed_images/Test/defective' --ext jpg --target-size "(256,256)"
# Out:
# 313 files to resize from directory `/content/gdrive/MyDrive/Test /defective` to target size:(256, 256)
# .........................................................................................................................................................................................................................................................................................................................
# Done resizing 313 files.
# Saved to directory: `/content/gdrive/MyDrive/compressed_images/Test/defective`

# %%
# !python resize_images.py --raw-dir '/content/gdrive/MyDrive/Test /good' --save-dir '/content/gdrive/MyDrive/compressed_images/Test/good' --ext jpg --target-size "(256,256)"
# Out:
# 264 files to resize from directory `/content/gdrive/MyDrive/Test /good` to target size:(256, 256)
# ........................................................................................................................................................................................................................................................................
# Done resizing 264 files.
# Saved to directory: `/content/gdrive/MyDrive/compressed_images/Test/good`
